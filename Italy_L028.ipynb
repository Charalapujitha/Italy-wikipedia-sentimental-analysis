# %%
pip install requests beautifulsoup4 pandas numpy matplotlib nltk textblob wordcloud scikit-learn imbalanced-learn streamlit
# Out:
# Requirement already satisfied: requests in c:\users\pujit\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\pujit\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\pujit\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\pujit\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\pujit\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: nltk in c:\users\pujit\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: textblob in c:\users\pujit\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: wordcloud in c:\users\pujit\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: scikit-learn in c:\users\pujit\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: imbalanced-learn in c:\users\pujit\anaconda3\lib\site-packages (0.12.3)
# Requirement already satisfied: streamlit in c:\users\pujit\anaconda3\lib\site-packages (1.40.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pujit\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pujit\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pujit\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pujit\anaconda3\lib\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pujit\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pujit\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pujit\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pujit\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pujit\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pujit\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pujit\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pujit\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pujit\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\pujit\anaconda3\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pujit\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: click in c:\users\pujit\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\pujit\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pujit\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\pujit\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\pujit\anaconda3\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pujit\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\pujit\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\pujit\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\pujit\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\pujit\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\pujit\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\pujit\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\pujit\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\pujit\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\pujit\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\pujit\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pujit\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\pujit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\pujit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\pujit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\pujit\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\pujit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 1: Web scrape Wikipedia page for Netherlands

import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from textblob import TextBlob
from wordcloud import WordCloud
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
import streamlit as st
import warnings
warnings.filterwarnings('ignore')

# %%
# Download required NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pujit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pujit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Step 1: Web scrape Wikipedia page for Netherlands
url = "https://en.wikipedia.org/wiki/Italy"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(f"Response Status: {response.status_code}")
print(f"Page Title: {soup.title.string}")
# Out:
# Response Status: 200
# Page Title: Italy - Wikipedia

# %%
# Step 2: Scrape only text
# Get all paragraphs from the main content
paragraphs = []

# Find the main content area
content_div = soup.find("div", {"id": "mw-content-text"})
if content_div:
    # Get all paragraphs within the main content area
    for p in content_div.find_all("p"):
        if p.text.strip():
            paragraphs.append(p.text)

# Combine all paragraphs into one text
raw_text = ' '.join(paragraphs)

print(f"Total characters extracted: {len(raw_text)}")
print(f"Preview of the text: {raw_text[:500]}...")
# Out:
# Total characters extracted: 93816
# Preview of the text: – in Europe (light green & dark grey)– in the European Union (light green)  –  [Legend] Italy,[a] officially the Italian Republic,[b] is a country in Southern and Western Europe.[c] It consists of a peninsula that extends into the Mediterranean Sea, with the Alps on its northern land border, as well as nearly 800 islands, notably Sicily and Sardinia. Italy shares land borders with France to the west; Switzerland and Austria to the north; Slovenia to the east; and the two enclaves of Vatican City...

# %%
# Step 3: Clean Text and preprocessing
def clean_text(text):
    # Remove citations [1], [2], etc.
    text = re.sub(r'\[\d+\]', '', text)
    # Remove special characters and digits
    text = re.sub(r'[^\w\s.]', '', text)
    # Replace multiple spaces with a single space
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

cleaned_text = clean_text(raw_text)

print(f"Total characters after cleaning: {len(cleaned_text)}")
print(f"Preview of the cleaned text: {cleaned_text[:500]}...")
# Out:
# Total characters after cleaning: 89335
# Preview of the cleaned text: in Europe light green dark grey in the European Union light green Legend Italya officially the Italian Republicb is a country in Southern and Western Europe.c It consists of a peninsula that extends into the Mediterranean Sea with the Alps on its northern land border as well as nearly 800 islands notably Sicily and Sardinia. Italy shares land borders with France to the west Switzerland and Austria to the north Slovenia to the east and the two enclaves of Vatican City and San Marino. It is the te...

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\pujit\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
# Step 4: Use Sentence Tokenizer and sentence tokenize
sentences = sent_tokenize(cleaned_text)
print(f"Total number of sentences: {len(sentences)}")
print(f"First 5 sentences:")
for i, sent in enumerate(sentences[:5]):
    print(f"{i+1}. {sent}")
# Out:
# Total number of sentences: 679
# First 5 sentences:
# 1. in Europe light green dark grey in the European Union light green Legend Italya officially the Italian Republicb is a country in Southern and Western Europe.c It consists of a peninsula that extends into the Mediterranean Sea with the Alps on its northern land border as well as nearly 800 islands notably Sicily and Sardinia.
# 2. Italy shares land borders with France to the west Switzerland and Austria to the north Slovenia to the east and the two enclaves of Vatican City and San Marino.
# 3. It is the tenthlargest country in Europe by area covering 301340 km2 116350 sq mi and the thirdmost populous member state of the European Union with nearly 60 million inhabitants.
# 4. Italys capital and largest city is Rome other major urban areas include Milan Naples Turin Palermo Bologna Florence Genoa and Venice.
# 5. The history of Italy goes back to numerous Italic peoplesnotably including the ancient Romans who conquered the Mediterranean world during the Roman Republic and ruled it for centuries during the Roman Empire.

# %%
# Step 5: Use TextBlob and analyze_sentiment() function to calculate sentiment of sentences
def get_sentiment(sentence):
    analysis = TextBlob(sentence)
    polarity = analysis.sentiment.polarity
    
    if polarity > 0.1:
        return 'positive'
    elif polarity < -0.1:
        return 'negative'
    else:
        return 'neutral'
    
# Calculate sentiment for each sentence
sentiment_results = []
for sentence in sentences:
    blob = TextBlob(sentence)
    polarity = blob.sentiment.polarity
    subjectivity = blob.sentiment.subjectivity
    sentiment = get_sentiment(sentence)
    
    sentiment_results.append({
        'sentence': sentence,
        'polarity': polarity,
        'subjectivity': subjectivity,
        'sentiment': sentiment
    })

# %%
# Step 6: Create a dataframe of sentences and sentiment
sentiment_df = pd.DataFrame(sentiment_results)

print(f"Dataframe shape: {sentiment_df.shape}")
print("\nFirst 5 rows of the sentiment dataframe:")
print(sentiment_df.head())

print("\nSentiment distribution:")
print(sentiment_df['sentiment'].value_counts())

# Visualize sentiment distribution
plt.figure(figsize=(8, 6))
sentiment_df['sentiment'].value_counts().plot(kind='bar', color=['gray', 'green', 'red'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Dataframe shape: (679, 4)
#
# First 5 rows of the sentiment dataframe:
#                                             sentence  polarity  subjectivity  \
# 0  in Europe light green dark grey in the Europea...  0.066667      0.283333
# 1  Italy shares land borders with France to the w...  0.000000      0.000000
# 2  It is the tenthlargest country in Europe by ar...  0.050000      0.200000
# 3  Italys capital and largest city is Rome other ... -0.020833      0.291667
# 4  The history of Italy goes back to numerous Ita...  0.000000      0.250000
#
#   sentiment
# 0   neutral
# 1   neutral
# 2   neutral
# 3   neutral
# 4   neutral
#
# Sentiment distribution:
# sentiment
# neutral     434
# positive    208
# negative     37
# Name: count, dtype: int64

# %%
# Step 7: Word tokenize the text data
words = word_tokenize(cleaned_text.lower())
print(f"Total words found: {len(words)}")
print(f"First 20 words: {words[:20]}")
# Out:
# Total words found: 14780
# First 20 words: ['in', 'europe', 'light', 'green', 'dark', 'grey', 'in', 'the', 'european', 'union', 'light', 'green', 'legend', 'italya', 'officially', 'the', 'italian', 'republicb', 'is', 'a']

# %%
# Step 8: Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]

print(f"Words after removing stopwords: {len(filtered_words)}")
print(f"First 20 filtered words: {filtered_words[:20]}")
# Out:
# Words after removing stopwords: 8201
# First 20 filtered words: ['europe', 'light', 'green', 'dark', 'grey', 'european', 'union', 'light', 'green', 'legend', 'italya', 'officially', 'italian', 'republicb', 'country', 'southern', 'western', 'consists', 'peninsula', 'extends']

# %%
# Step 9: Wordcloud of data
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(filtered_words))

plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('WordCloud for Netherlands Wikipedia')
plt.tight_layout()
plt.show()

# %%
# Step 10: Frequent Words with frequency counts
word_freq = Counter(filtered_words)
common_words = word_freq.most_common(20)

print("Top 20 frequent words:")
for word, count in common_words:
    print(f"{word}: {count}")

# Visualize top 20 words
plt.figure(figsize=(12, 8))
words_df = pd.DataFrame(common_words, columns=['word', 'count'])
plt.barh(words_df['word'], words_df['count'], color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 20 Frequent Words')
plt.gca().invert_yaxis()  # To display the most frequent word at the top
plt.tight_layout()
plt.show()
# Out:
# Top 20 frequent words:
# italy: 204
# italian: 169
# world: 49
# country: 36
# europe: 34
# roman: 33
# century: 32
# war: 32
# one: 31
# first: 30
# rome: 29
# european: 28
# italys: 28
# national: 28
# largest: 24
# include: 24
# north: 23
# political: 23
# among: 22
# western: 21

# %%
# Step 11: Apply TFIDF Vectorizer on sentences and sentiment dataframe
# Step 12: Use only positive and negative sentiments only & ignore neutral
filtered_sentiment_df = sentiment_df[sentiment_df['sentiment'] != 'neutral']
print(f"Dataframe shape after removing neutral sentiments: {filtered_sentiment_df.shape}")
print(filtered_sentiment_df['sentiment'].value_counts())

# Prepare data for ML models
X = filtered_sentiment_df['sentence']
y = filtered_sentiment_df['sentiment']

# Convert text to TFIDF features
tfidf_vectorizer = TfidfVectorizer(max_features=5000, min_df=2)
X_tfidf = tfidf_vectorizer.fit_transform(X)

print(f"TFIDF matrix shape: {X_tfidf.shape}")
# Out:
# Dataframe shape after removing neutral sentiments: (245, 4)
# sentiment
# positive    208
# negative     37
# Name: count, dtype: int64
# TFIDF matrix shape: (245, 573)

# %%
# Step 13: Use SMOTE to balance sentiment
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Apply SMOTE for balancing
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print("Before SMOTE:", pd.Series(y_train).value_counts())
print("After SMOTE:", pd.Series(y_train_smote).value_counts())
# Out:
# Before SMOTE: sentiment
# positive    169
# negative     27
# Name: count, dtype: int64
# After SMOTE: sentiment
# positive    169
# negative    169
# Name: count, dtype: int64

# %%
# Step 14: Build machine learning models
def evaluate_model(model, X_train, X_test, y_train, y_test, model_name):
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    
    print(f"Model: {model_name}")
    print(f"Accuracy: {accuracy:.4f}")
    print("Classification Report:")
    print(report)
    print("-" * 80)
    
    return model

# a) Binary Logistic Regression
logreg_model = evaluate_model(
    LogisticRegression(max_iter=1000, random_state=42),
    X_train_smote, X_test, y_train_smote, y_test,
    "Logistic Regression"
)

# b) Decision Tree
dt_model = evaluate_model(
    DecisionTreeClassifier(random_state=42),
    X_train_smote, X_test, y_train_smote, y_test,
    "Decision Tree"
)

# c) Random Forest
rf_model = evaluate_model(
    RandomForestClassifier(n_estimators=100, random_state=42),
    X_train_smote, X_test, y_train_smote, y_test,
    "Random Forest"
)

# d) Gradient Boosting
gb_model = evaluate_model(
    GradientBoostingClassifier(n_estimators=100, random_state=42),
    X_train_smote, X_test, y_train_smote, y_test,
    "Gradient Boosting"
)

# e) Naïve Bayes
nb_model = evaluate_model(
    MultinomialNB(),
    X_train_smote, X_test, y_train_smote, y_test,
    "Naive Bayes"
)

# f) K Nearest Neighbors
knn_model = evaluate_model(
    KNeighborsClassifier(n_neighbors=5),
    X_train_smote, X_test, y_train_smote, y_test,
    "K-Nearest Neighbors"
)

# Choose the best performing model (for example, Logistic Regression)
# We'll use this model in our Streamlit app
best_model = logreg_model
print(f"Selected model for Streamlit app: Logistic Regression")
# Out:
# Model: Logistic Regression
# Accuracy: 0.7959
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.10      0.17        10
#     positive       0.81      0.97      0.88        39
#
#     accuracy                           0.80        49
#    macro avg       0.65      0.54      0.53        49
# weighted avg       0.75      0.80      0.74        49
#
# --------------------------------------------------------------------------------
# Model: Decision Tree
# Accuracy: 0.7347
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.36      0.40      0.38        10
#     positive       0.84      0.82      0.83        39
#
#     accuracy                           0.73        49
#    macro avg       0.60      0.61      0.61        49
# weighted avg       0.74      0.73      0.74        49
#
# --------------------------------------------------------------------------------
# Model: Random Forest
# Accuracy: 0.7959
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        10
#     positive       0.80      1.00      0.89        39
#
#     accuracy                           0.80        49
#    macro avg       0.40      0.50      0.44        49
# weighted avg       0.63      0.80      0.71        49
#
# --------------------------------------------------------------------------------
# Model: Gradient Boosting
# Accuracy: 0.7755
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.33      0.10      0.15        10
#     positive       0.80      0.95      0.87        39
#
#     accuracy                           0.78        49
#    macro avg       0.57      0.52      0.51        49
# weighted avg       0.71      0.78      0.72        49
#
# --------------------------------------------------------------------------------
# Model: Naive Bayes
# Accuracy: 0.7347
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.40      0.60      0.48        10
#     positive       0.88      0.77      0.82        39
#
#     accuracy                           0.73        49
#    macro avg       0.64      0.68      0.65        49
# weighted avg       0.78      0.73      0.75        49
#
# --------------------------------------------------------------------------------
# Model: K-Nearest Neighbors
# Accuracy: 0.2041
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative       0.20      1.00      0.34        10
#     positive       0.00      0.00      0.00        39
#
#     accuracy                           0.20        49
#    macro avg       0.10      0.50      0.17        49
# weighted avg       0.04      0.20      0.07        49
#
# --------------------------------------------------------------------------------
# Selected model for Streamlit app: Logistic Regression

# %%
# Save the vectorizer and model for the Streamlit app
import pickle

with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf_vectorizer, f)
    
with open('sentiment_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)
